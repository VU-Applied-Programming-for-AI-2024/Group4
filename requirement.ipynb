# %%
# !pip uninstall numpy
# Out:
# ^C

# %%
pip

# %%
# !pip install torch
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ---------------------------------------- 0.0/2.7 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.7 GB 8.9 MB/s eta 0:05:00
#      ---------------------------------------- 0.0/2.7 GB 13.1 MB/s eta 0:03:24
#      ---------------------------------------- 0.0/2.7 GB 13.8 MB/s eta 0:03:13
#      ---------------------------------------- 0.0/2.7 GB 13.8 MB/s eta 0:03:14
#      ---------------------------------------- 0.0/2.7 GB 14.1 MB/s eta 0:03:10
#      ---------------------------------------- 0.0/2.7 GB 14.2 MB/s eta 0:03:09
#      ---------------------------------------- 0.0/2.7 GB 14.0 MB/s eta 0:03:11
#      ---------------------------------------- 0.0/2.7 GB 14.2 MB/s eta 0:03:08
#      ---------------------------------------- 0.0/2.7 GB 14.2 MB/s eta 0:03:08
#      ---------------------------------------- 0.0/2.7 GB 14.2 MB/s eta 0:03:08
# ...
